# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV file
df = pd.read_csv('summary.csv')

#replace Embedded in data with Co-Clustering On Embedded Data
df['Type'] = df['Type'].replace('Embedded', 'Co-Clustering On Embedded Data')
#replace simple_clustering with Traditional Clustering on Embedded Data
df['Type'] = df['Type'].replace('simple_clustering', 'Traditional Clustering on Embedded Data')
# Aggregate mean MSE for all methods
mean_mse = df.groupby(['Technique', 'Type'])['MSE'].mean().reset_index()

# Plot the mean MSE for all aggregated methods
plt.figure(figsize=(14, 7))
sns.barplot(x='Type', y='MSE', hue='Technique', data=mean_mse, palette='viridis')
plt.xlabel('Type')
plt.ylabel('Mean MSE')
plt.title('Mean MSE for All Aggregated Methods')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('mean_mse_all_methods.png')

# %%
df.groupby(['Technique'])['MSE'].mean().reset_index()
# Out:
#        Technique       MSE
# 0     Clustering  0.790140
# 1  Co-Clustering  0.821377

# %%
# Box plot of MSE for all methods
plt.figure(figsize=(14, 7))
sns.boxplot(x='Type', y='MSE', hue='Technique', data=df, palette='viridis')
plt.xlabel('Type')
plt.ylabel('MSE')
plt.title('Box plot of MSE for All Methods')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
# plt.savefig('mse_all_methods.png')

# %%
df
# Out:
#          Technique                                     Type  \
# 0       Clustering                 Complex_Network_Embedded
# 1       Clustering  Traditional Clustering on Embedded Data
# 2       Clustering  Traditional Clustering on Embedded Data
# 3       Clustering  Traditional Clustering on Embedded Data
# 4       Clustering  Traditional Clustering on Embedded Data
# ..             ...                                      ...
# 177     Clustering  Traditional Clustering on Embedded Data
# 178  Co-Clustering                    Spectral-BiClustering
# 179     Clustering  Traditional Clustering on Embedded Data
# 180     Clustering                 Complex_Network_Embedded
# 181     Clustering                 Complex_Network_Raw_Data
#
#                     Date       MSE
# 0    2024-06-16_10-17-14  0.793236
# 1    2024-06-30_23-23-41  0.833381
# 2    2024-06-30_23-25-29  0.760468
# 3    2024-06-30_23-25-26  0.743738
# 4    2024-06-30_23-23-49  0.752360
# ..                   ...       ...
# 177  2024-07-08_10-36-58  0.857495
# 178  2024-07-22_12-28-04  0.915416
# 179  2024-06-30_23-25-30  0.724063
# 180  2024-07-08_10-44-05  0.710021
# 181  2024-06-10_10-14-30  0.750058
#
# [182 rows x 4 columns]
