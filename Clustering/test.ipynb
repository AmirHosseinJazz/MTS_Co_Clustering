# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create the data frame from the provided clustering results
data = {
    'Sample': list(range(180)),
    'Cluster': [
        1, 1, 1, 1, 1, 1, 1, 2, 1, 2, 1, 2, 1, 1, 1, 0, 2, 2, 2, 1, 2, 1, 1, 2, 2, 1, 1, 1, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 1, 0, 
        1, 1, 1, 1, 2, 0, 1, 2, 2, 0, 2, 2, 1, 1, 1, 1, 2, 2, 2, 2, 2, 1, 2, 1, 0, 1, 1, 0, 2, 1, 1, 2, 2, 2, 2, 1, 1, 2, 0, 2, 
        1, 2, 1, 2, 1, 1, 1, 2, 1, 1, 0, 1, 1, 1, 2, 1, 1, 2, 1, 2, 2, 1, 2, 2, 2, 0, 1, 1, 2, 2, 1, 2, 2, 1, 1, 2, 1, 2, 0, 1, 
        2, 1, 1, 2, 2, 2, 1, 2, 1, 1, 1, 1, 1, 2, 1, 1, 1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, 1, 2, 1, 1, 0, 1, 1, 1, 1, 2, 
        1, 1, 2, 0, 1, 2, 2, 1, 1, 1, 2, 2, 2, 2, 2, 1, 2, 2, 1, 0
    ]
}

df = pd.DataFrame(data)

# Create a bar plot to visualize the distribution of samples across clusters
plt.figure(figsize=(10, 6))
df['Cluster'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Samples Across Clusters')
plt.xlabel('Cluster')
plt.ylabel('Number of Samples')
plt.xticks(rotation=0)
plt.grid(axis='y')

# Save the figure
plt.savefig('cluster_distribution.png')

# Show the plot
plt.show()
